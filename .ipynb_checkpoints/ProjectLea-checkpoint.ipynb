# %% [markdown]
# # Climate

# %% [markdown]
# In this project climate data for a city in Bavaria, Germany, is read in, the data is cleaned and made more readable and in the following analyzed using different statistical methods.
# Since my research does not include working with data sets, I wanted to use this project to learn more about data science, i.e. working with data sets and presenting them. Moreover, I did some literature search on how to present climate data and apply some statistical methods on it.
# The project work consisted of the following steps: searching for freely available climate data sets, reading in the data and getting a first overview, followed by some literature search on how to work with and interpret climate data.
# *more about the project here*

# %% [markdown]
# ## General Information

# %% [markdown]
# The following map of Europe shows where Regensburg is located and provides some basic information about the city.

# %%
import geopandas as gpd
from bokeh.plotting import figure
from bokeh.io import show, output_notebook
from bokeh.palettes import Category10
from bokeh.models import GeoJSONDataSource, ColumnDataSource, HoverTool, Title
from bokeh.transform import factor_cmap
from bokeh.models.widgets import Slider
from bokeh.layouts import column, row, WidgetBox

# %%
RGBGdata = pd.DataFrame({'country': 'Germany', 'state': 'Bavaria', 'station': 'Regensburg', 'area': [8076], 'population': [153094],
                       'lat': [49.1], 'lon': [12.5]})

source = ColumnDataSource( data = RGBGdata )

location = {'RGBG': {'lat':49.1,'lon':12.5}}

europe = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
geo_source = GeoJSONDataSource(geojson=europe.to_json())

#get map with tools on the left (they are self-explaining)
p = figure(tools = "pan, wheel_zoom, reset", x_range = (-30, 60), y_range = (30, 85), 
           x_axis_location=None, y_axis_location=None, plot_width=800, plot_height=700)

p.title.text = 'Map of Europe with Regensburg'

p.add_layout(Title(text='Data taken from Wikipedia https://en.wikipedia.org/wiki/Regensburg', align='left',
       text_font_size="10px", text_color='blue'), "below")

#remove grid on map
p.xgrid.visible = False
p.ygrid.visible = False

p.patches('xs', 'ys', fill_alpha=0,
    line_color=Category10[10][7], line_width=1.5, source=geo_source)

glyph = p.scatter('lon','lat', source = source, 
              size = 5, fill_alpha = .5, hover_fill_alpha = 1.0,
              marker = 'circle',
              legend_label = 'Regensburg')

glyph_hover = HoverTool(renderers=[glyph],
                         tooltips=[('Sation','@station'),('Longitude','@lon E'), ('Latitude','@lat N'),
                                  ('Country','@country'), ('State','@state'), ('Population','@population'),
                                  ('Area','@area')])
p.add_tools(glyph_hover)

p.title.align = 'center'
p.legend.location = 'top_left'

output_notebook()
show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9608">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="1c1affdf-b362-454d-8a68-0822a5004cd9" data-root-id="9554"></div>

# %% [markdown]
# ## Data

# %% [markdown]
# The data is downoladed from [this url](https://www.dwd.de/DE/leistungen/klimadatendeutschland/klarchivtagmonat.html?nn=16102) and provides weather data for the Germay city Regensburg.

# %%
#from IPython.display import IFrame
#from IPython.display import YouTubeVideo

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Data preparation
# Read in the data, clean it and make it more readable.

# %% [markdown]
# Read in the data given as a text file using pandas.

# %%
df = pd.read_table('Data/produkt_klima_tag_18790101_20191231_04104.txt',header=0,sep=';|\t',engine='python')

# %%
df.head() #check at how the data actually looks like in the beginnign
# Out:
#    STATIONS_ID  MESS_DATUM  QN_3     FX     FM  QN_4   RSK  RSKF    SDK  \
# 0         4104    18790101  -999 -999.0 -999.0     1   2.2     1 -999.0
# 1         4104    18790102  -999 -999.0 -999.0     1   0.5     7 -999.0
# 2         4104    18790103  -999 -999.0 -999.0     1   3.9     8 -999.0
# 3         4104    18790104  -999 -999.0 -999.0     1   0.3     7 -999.0
# 4         4104    18790105  -999 -999.0 -999.0     1   0.6     7 -999.0
#
#    SHK_TAG     NM   VPM     PM   TMK   UPM   TXK   TNK    TGK  eor
# 0     -999    4.0   6.0  972.0   4.4  72.0   9.3   1.5 -999.0  eor
# 1     -999 -999.0   5.7  965.5   3.3  69.0   8.1   0.6 -999.0  eor
# 2     -999 -999.0   5.1  967.1   0.5  83.0   1.9  -3.0 -999.0  eor
# 3     -999 -999.0   6.5  960.6   3.6  78.0   8.1   0.1 -999.0  eor
# 4     -999    6.7   4.7  972.4  -0.3  80.0   1.5  -2.5 -999.0  eor

# %% [markdown]
# Clean the data, i.e. delere unnecessary columns or columns that are not of interest for this project.

# %%
df.drop(columns='STATIONS_ID',inplace=True) #delete the unnecessary station ID column, we consider only one station ID
df.drop(columns='QN_3',inplace=True) #delete the column describing the measurement quality
df.drop(columns='QN_4',inplace=True) #delete the column describing the measurement quality
df.drop(columns='eor',inplace=True) #delete the unnecessary eor (end of row) column
#df.head()

# %% [markdown]
# Change the names in the table since they are not clear. Description of the abbreviations can be found (in German) in the html file.

# %%
df.columns = ['date','max wind peak value','average wind velocity','precipitation level',
                         'precipitation level num','sun hours','snow height',
                         'average degree of coverage','average degree of vaport pressure',
                         'average air pressure','average temperature','average relative humidity',
                         'max temperature','min temperature','min temperature 5cm']
#df.head()

# %% [markdown]
# Replace the index by the date information and replace it by pandas datetime form and create multiindex for year-month-day.

# %%
df.set_index(['date'],inplace=True)
df.index = pd.to_datetime(df.index, format='%Y%m%d') #use pandas datetime option
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year
df.set_index(['year','month','day'],inplace=True)
#df.head()

# %%
df = df.replace([-999],np.nan) #replace all non-given values (-999) by numpy NaN

# %%
df.head() #check how the data looks now
# Out:
#                 max wind peak value  average wind velocity  \
# year month day
# 1879 1     1                    NaN                    NaN
#            2                    NaN                    NaN
#            3                    NaN                    NaN
#            4                    NaN                    NaN
#            5                    NaN                    NaN
#
#                 precipitation level  precipitation level num  sun hours  \
# year month day
# 1879 1     1                    2.2                      1.0        NaN
#            2                    0.5                      7.0        NaN
#            3                    3.9                      8.0        NaN
#            4                    0.3                      7.0        NaN
#            5                    0.6                      7.0        NaN
#
#                 snow height  average degree of coverage  \
# year month day
# 1879 1     1            NaN                         4.0
# ...

# %% [markdown]
# Safe the processed data to the disk.

# %%
output = pd.ExcelWriter('data/ClimateRgbg.xlsx')
df.to_excel(output,'Sheet1',index=False)
output.save()

# %%
df.to_csv('data/wasgen.csv')

# %% [markdown]
# ## Data visualization

# %%
plt.rcParams.update({ 'figure.figsize': [5,3.5], 'font.size': 14 })

fig = plt.figure()
ax = plt.axes()
ax.plot(pd.to_numeric(df['max temperature']).groupby(['year']).agg(['max']),'*--')

ax.set_xlabel('Year',fontsize=14,labelpad=8)
ax.set_ylabel('Max temperature (°C)',fontsize=14,labelpad=8)

#fig.savefig ("maxTemp.svg", format = "svg", dpi = 300)
# Out:
# Text(0, 0.5, 'Max temperature (°C)')

# %%
df.sort_values('max temperature',ascending=False).iloc[0].name
# Out:
# (1983, 7, 27)

# %%
df.loc[2000,12]['average temperature'].mean()
# Out:
# 1.596774193548387

# %%
from ipywidgets import interact, interactive, fixed

# %%
@interact(option={'max temperature':'max','min temperature':'min','average temperature':'aver','temperature range':'range'})
def plotTemperature(option):
    plt.rcParams.update({ 'figure.figsize': [5,3.5], 'font.size': 14 })

    fig = plt.figure()
    ax = plt.axes()
    if option=='max':
        ax.plot(pd.to_numeric(df['max temperature']).groupby(['year']).agg(['max']),'*--')
        ax.set_ylabel('Max temperature (°C)',fontsize=14,labelpad=8)
    if option=='min':
        ax.plot(pd.to_numeric(df['min temperature']).groupby(['year']).agg(['min']),'*--')
        ax.set_ylabel('Max temperature (°C)',fontsize=14,labelpad=8)
    if option=='aver':
        ax.plot(pd.to_numeric(df['average temperature']).groupby(['year']).agg(['mean']),'*--')
        ax.set_ylabel('Average temperature (°C)',fontsize=14,labelpad=8)
    if option=='range':
        a = pd.to_numeric(df['average temperature']).groupby(['year']).agg(['mean'])
        ax.plot(a,'b-')
        
        ma = pd.to_numeric(df['max temperature']).groupby(['year']).agg(['max'])
        mi = pd.to_numeric(df['min temperature']).groupby(['year']).agg(['min'])
        ax.plot(ma,'*--')
        ax.plot(mi,'*--')
        #ax.fill_between(a.index, ma.values, mi.values, alpha=.5)
        
        ax.set_ylabel('Temperature range (°C)',fontsize=14,labelpad=8)
        
    ax.set_xlabel('Year',fontsize=14,labelpad=8)
    #ax.set_xticks([1970,1990,2010])
    #ax.set_xticklabels([1970,1990,2010],fontsize=14,labelpad=8)


#interactive_plot = interactive(plotTemperature,option)
#interactive_plot.children[0].description=r'Choose $\nu$' # slider interactive_plot``
#interactive_plot.children[1].description=r'Choose $\Gamma$'
display(plotTemperature)
# Out:
# interactive(children=(Dropdown(description='option', options={'max temperature': 'max', 'min temperature': 'mi…
# <function __main__.plotTemperature(option)>

# %% [markdown]
# Now plot the rain, snow and sun data per year/month.

# %%
def rain(year):
    if (year in df.index) == False:
        print('No data available for the year {}!'.format(year))
    else:
        test = df.loc[year]
        pd.to_numeric(test['precipitation level']).groupby(['month']).agg(['mean']).plot.bar()
        plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                            'October','November','December'), rotation=45)
        plt.xlabel('Month',fontsize=14,labelpad=8)
        plt.ylabel('Average monthly rainfall (mm)',fontsize=14,labelpad=8)  
        plt.title('{}'.format(year),fontsize=14)
        
import ipywidgets as widgets

interactive_plot = interactive(rain,year=widgets.IntSlider(min=1879, max=2019, step=1, value=1990,continuous_update=False))
interactive_plot.children[0].description=r'Choose year' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1990, continuous_update=False, description='Choose year', max=2019, min=…

# %%
def rain(year):
    if (year in df.index) == False:
        print('No data available for the year {}!'.format(year))
    else:
        test = df.loc[year]

        if (any(test['precipitation level'] == 'NaN')) == True:
            print('No rain data available for the year {}!'.format(year))
        else:
            pd.to_numeric(test['precipitation level']).groupby(['month']).agg(['mean']).plot.bar(color='blue')
            plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                            'October','November','December'), rotation=45)
            plt.xlabel('Month',fontsize=14,labelpad=8)
            plt.ylabel('Average monthly rainfall (mm)',fontsize=14,labelpad=8)  
            plt.title('{}'.format(year),fontsize=14)

        if (any(test['sun hours'] == 'NaN')) == True:
            print('No sun data available for the year {}!'.format(year))
        else:
            pd.to_numeric(test['sun hours']).groupby(['month']).agg(['mean']).plot.bar(color='red')
            plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                            'October','November','December'), rotation=45)
            plt.xlabel('Month',fontsize=14,labelpad=8)
            plt.ylabel('Average monthly sun (h)',fontsize=14,labelpad=8)  
            plt.title('{}'.format(year),fontsize=14)

        if (any(test['snow height'] == 'NaN')) == True:
            print('No snow data available for the year {}!'.format(year))
        else:
            pd.to_numeric(test['snow height']).groupby(['month']).agg(['mean']).plot.bar()
            plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                            'October','November','December'), rotation=45)
            plt.xlabel('Month',fontsize=14,labelpad=8)
            plt.ylabel('Average snow height (cm)',fontsize=14,labelpad=8)  
            plt.title('{}'.format(year),fontsize=14)
        
import ipywidgets as widgets

interactive_plot = interactive(rain,year=widgets.IntSlider(min=1879, max=2019, step=1, value=1990,continuous_update=False))
interactive_plot.children[0].description=r'Choose year' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1990, continuous_update=False, description='Choose year', max=2019, min=…

# %% [markdown]
# Average temperature per year.

# %%
def plotTemperature(month):
    plt.rcParams.update({ 'figure.figsize': [5,3.5], 'font.size': 14 })

    fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(5, 3))
    
    ax[0].plot(pd.to_numeric(df['average temperature']).groupby(['year']).agg(['mean']),'*--')
    ax[0].set_ylabel('Average temperature (°C)',fontsize=14,labelpad=8) 
    ax[0].set_xlabel('Year',fontsize=14,labelpad=8)
    ax[0].set_title('Yearly')
    
    ax[1].plot(pd.to_numeric(df['average temperature']).groupby(['year','month']).agg(['mean'])['mean'][:,month])
    ax[1].set_xlabel('Year',fontsize=14,labelpad=8)
    ax[1].set_ylabel('Average temperature (°C)',fontsize=14,labelpad=8)  
    ax[1].set_title('{}'.format(month),fontsize=14)
    ax[1].set_title('Monthly')
    ax[1].yaxis.set_ticks_position('right')
    ax[1].yaxis.set_label_position("right")
    
    fig.tight_layout()
    
interactive_plot = interactive(plotTemperature,month=widgets.IntSlider(min=1, max=12, step=1, value=1,continuous_update=False))
interactive_plot.children[0].description=r'Month' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1, continuous_update=False, description='Month', max=12, min=1), Output(…

# %% [markdown]
# # Some statistics

# %% [markdown]
# Use linear regression to see an overall temperature trend, i.e. if we can notice the climate change. The theory is taken from [this book](https://eds.b.ebscohost.com/eds/detail/detail?vid=2&sid=68a4b26f-fdd9-4747-95f2-40e5d7637ebc%40sessionmgr102&bdata=JnNpdGU9ZWRzLWxpdmUmc2NvcGU9c2l0ZQ%3d%3d#AN=lub.5961074&db=cat07147a), which is available as ebook in the LU library. More explanation to the used methods can be found there.

# %% [markdown]
# We are interested in the trend of the yearly average temperature. To this end, we calculate the mean temperature for each year. In order to see a trend over the year, we use polynomial regression to fit a polynomial describing the temperature trends, i.e. the long-term variation of this time series.

# %%
data = pd.to_numeric(df['average temperature']).groupby(['year']).agg(['mean'])
x = data.index.values.reshape(-1,1)
y = data.iloc[:,0].values.reshape(-1,1)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
order = 4
poly_reg = PolynomialFeatures(degree=order)
X_poly = poly_reg.fit_transform(x)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

plt.plot(x, y, label='yearly average')
plt.plot(x, pol_reg.predict(poly_reg.fit_transform(x)), label='linear regression')
plt.xticks([1880,1900,1920,1940,1960,1980,2000,2019], [1897,1900,1920,1940,1960,1980,2000,2019])
plt.title('Linear Regression of order {}'.format(order))
plt.xlabel('year')
plt.ylabel('average temperature (°C)')
plt.legend()
plt.show()

# %% [markdown]
# From the previous figure it is obvious that the temperature average increased between 1879 and 2019.

# %% [markdown]
# We can calculate the residual between the fitted polynomial $p_t$ and the actual time series $y_t$ for each year $t$, which allows to measure the goodness-of-fit using the mean sum of the squared residuals (MSQ):
# $$
# \sqrt{\frac{1}{n}\sum_{t=1}^{n}(y_t-p_t)^2}.
# $$
# A smaller value indicates a better polynomial approximation.
# For the given approximation we can calculate the *goodness-of-fit measure*:

# %%
p = pol_reg.predict(poly_reg.fit_transform(x))
L = (y-p)**2
L2 = [(1/(i+1))*L[i] for i in range(len(L))]
print('goodness-of-fit measure:',np.sqrt(sum(L2)))
# Out:
# goodness-of-fit measure: [1.62267478]

# %% [markdown]
# Next, we want to produce some trend curves, as described in the book (chapter 2). This is done by computing *moving averages* over $k$ years with $k=2l+1$. We can calculate a trend temperature $m_t$ in a time interval $[t-l,t+t]$ as an average over $k$ years centered at $t$ and weighting the endpoints by $\frac{1}{2}$:
# $$
# m_t = \frac{1}{2l}\left(\frac{1}{2}y_{t-l}+y_{t-l+1}+\dots+y_t+\dots+y_{t+l-1}+\frac{1}{2}y_{t+l}\right).
# $$
# The folowing function computes for a time series $\texttt{x}$ the trend over $\texttt{k}$ years:

# %%
def trend(x,k):
    #computes the trend function for a time series x for k years, k needs to be odd!
    l = int((k-1)/2)
    y = np.zeros(len(x)-2*l)
    for i in range(len(x)-2*l):
        t = i+l
        y[i] = sum(x[t-l+1:t+l]) + 0.5*(x[t-l]+x[t+l])
    return 1/(2*l)*y

# %%
def trendPlot(k):
    
    z = trend(y,k)
    l = int((k-1)/2)
    plt.plot(x[l:-l],z,label='centered moving averages')
    
    plt.plot(x, y, label='yearly average')
    plt.xticks([1880,1900,1920,1940,1960,1980,2000,2019], [1897,1900,1920,1940,1960,1980,2000,2019])
    plt.title('Yearly average temperature and trend with means of {} years'.format(k))
    plt.xlabel('year')
    plt.ylabel('average temperature (°C)')
    plt.legend()
    plt.show()

interactive_plot = interactive(trendPlot,k=widgets.IntSlider(min=3, max=11, step=2, value=1,continuous_update=False))
interactive_plot.children[0].description=r'Choose k' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=3, continuous_update=False, description='Choose k', max=11, min=3, step=…

# %% [markdown]
# It is also interesting to look at the oscillation of climatological series. These are calculated considering moving 10-year blocks $[t-9,t]$ and calcualting the standard deviation for each block.

# %%
# importing Statistics module
import statistics
  
def Oscillation(x,k):
    y = np.zeros(len(x)-k)
    for i in range(len(x)-k):
        t = i+k
        y[i] = statistics.stdev(x[t-k:t+1])
    return y

Oscillation(y[:,0],9)

plt.plot(x[10:], Oscillation(y[:,0],10))
plt.xticks([1880,1900,1920,1940,1960,1980,2000,2019], [1897,1900,1920,1940,1960,1980,2000,2019])
plt.title('Oscillation yearly average temperature')
plt.xlabel('year')
plt.ylabel('standard deviation temperature (°C)')
plt.show()

# %% [markdown]
# Next we can look at some monthly values over the years.

# %%
#first, remove years with no data

def MonthlyTempPlots(year):

    tempData = df['average temperature'] #get data frame with just average temperature
    tempData.dropna(inplace=True) #drop all NaN years
    
    if (year in df.index) == False:
        print('No data available for the year {}!'.format(year))
        
        (pd.to_numeric(tempData).groupby(['month']).agg(['mean'])).plot.bar()
        plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                                'October','November','December'), rotation=45)
        plt.ylabel('Average temperature (°C)',fontsize=14,labelpad=8) 
        plt.xlabel('month',fontsize=14,labelpad=8)
        plt.title('All years')
        plt.ylim([-12,25])
        plt.legend().remove()
        
    else:

        fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(9, 7))
    
        (pd.to_numeric(tempData).groupby(['month']).agg(['mean'])).plot.bar(ax=ax[0])
        ax[0].set_xticks(np.arange(12)) 
        ax[0].set_xticklabels(['January','February','March','April','May','June','July','August','September',
                                'October','November','December'], rotation=45)
        ax[0].set_ylabel('Average temperature (°C)',fontsize=14,labelpad=8) 
        ax[0].set_xlabel('month',fontsize=14,labelpad=8)
        ax[0].set_title('All years')
        ax[0].set_ylim([-12,25])
        ax[0].get_legend().remove()
    
        #(pd.to_numeric(df.loc[year]['average temperature']).groupby(['month']).agg(['mean'])).plot.bar(ax=ax[1])
        (pd.to_numeric(tempData.loc[year]).groupby(['month']).agg(['mean'])).plot.bar(ax=ax[1])
        ax[1].set_xticks(np.arange(12)) 
        ax[1].set_xticklabels(['January','February','March','April','May','June','July','August','September',
                                'October','November','December'], rotation=45)
        ax[1].set_ylabel('Average temperature (°C)',fontsize=14,labelpad=8)  
        ax[1].set_title('{}'.format(year),fontsize=14)
        ax[1].set_title('{}'.format(year))
        ax[1].set_ylim([-12,25])
        ax[1].yaxis.set_ticks_position('right')
        ax[1].yaxis.set_label_position("right")
        ax[1].get_legend().remove()
    
        fig.tight_layout()
    
interactive_plot = interactive(MonthlyTempPlots,year=widgets.IntSlider(min=1879, max=2019, step=1, value=1990,continuous_update=False))
interactive_plot.children[0].description=r'Year' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1990, continuous_update=False, description='Year', max=2019, min=1879), …

# %% [markdown]
# In order to be able to classify the climate zone of Regensburg, we also need to consider the precipitation level.

# %%
def MonthlyRainPlots(year):
    
    rainData = df['precipitation level'] #get data frame with just precipitation level
    rainData.dropna(inplace=True) #drop all NaN years
    
    if (year in rainData.index) == False:
        print('No data available for the year {}!'.format(year))
        
        (pd.to_numeric(rainData).groupby(['month']).agg(['mean'])).plot.bar()
        plt.xticks(np.arange(12), ('January','February','March','April','May','June','July','August','September',
                                'October','November','December'), rotation=45)
        plt.ylabel('Average precipitation (mm)',fontsize=14,labelpad=8) 
        plt.xlabel('month',fontsize=14,labelpad=8)
        plt.title('All years')
        plt.ylim([0,5])
        plt.legend().remove()
        
    else:

        fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(9, 7))
    
        (pd.to_numeric(rainData).groupby(['month']).agg(['mean'])).plot.bar(ax=ax[0])
        ax[0].set_xticks(np.arange(12)) 
        ax[0].set_xticklabels(['January','February','March','April','May','June','July','August','September',
                                'October','November','December'], rotation=45)
        ax[0].set_ylabel('Average precipitation (mm)',fontsize=14,labelpad=8) 
        ax[0].set_xlabel('month',fontsize=14,labelpad=8)
        ax[0].set_title('All years')
        ax[0].set_ylim([0,5])
        ax[0].get_legend().remove()
    
        (pd.to_numeric(rainData.loc[year]).groupby(['month']).agg(['mean'])).plot.bar(ax=ax[1])
        ax[1].set_xticks(np.arange(12)) 
        ax[1].set_xticklabels(['January','February','March','April','May','June','July','August','September',
                                'October','November','December'], rotation=45)
        ax[1].set_ylabel('Average precipitation (mm)',fontsize=14,labelpad=8)  
        ax[1].set_title('{}'.format(year),fontsize=14)
        ax[1].set_title('{}'.format(year))
        ax[1].set_ylim([0,5])
        ax[1].yaxis.set_ticks_position('right')
        ax[1].yaxis.set_label_position("right")
        ax[1].get_legend().remove()
    
        fig.tight_layout()
    
interactive_plot = interactive(MonthlyRainPlots,year=widgets.IntSlider(min=1879, max=2019, step=1, value=1990,continuous_update=False))
interactive_plot.children[0].description=r'Year' # slider interactive_plot
display(interactive_plot)
# Out:
# interactive(children=(IntSlider(value=1990, continuous_update=False, description='Year', max=2019, min=1879), …

# %% [markdown]
# Due to the [Köppen climate classification](https://en.wikipedia.org/wiki/Köppen_climate_classification) the climate in Regensburg can be classified between humid continental (Dfb) and oceanic (Cfb)
# climate.

# %% [markdown]
# Next we look at the correlation. This is an indication for how the value of a parameter at time point $t$ is correlated with the value at time point $t+1$. We therefore make a scatter plot and calculate the correlation coefficient.

# %%
mt = pd.to_numeric(df['average temperature']).groupby(['year','month']).agg(['mean'])['mean'] #monthly mean temperature

corr = np.corrcoef(mt[:-1],mt[1:])[0,1]
plt.scatter(mt[:-1],mt[1:],label='correlation coefficient: {:.3f}'.format(corr))
plt.xlabel('$y_t$ (°C)')
plt.ylabel('$y_{t+1}$ (°C)')
plt.legend()
plt.title('Correlation monthly temperature average')
# Out:
# Text(0.5, 1.0, 'Correlation monthly temperature average')

# %% [markdown]
# We notice that the correlation coefficient is $r \approx 0.835$. The large value is owed to the seasonal effects, i.e., to the course of the monthly temperatures over the calendar year. It contains, so to say, much redundant information

# %%
tempData = df['average temperature'] #get data frame with just average temperature
tempData.dropna(inplace=True) 
av = pd.to_numeric(tempData).groupby(['month']).agg(['mean'])
d1 = pd.DataFrame(mt)
rr = d1-av

corr = np.corrcoef(rr['mean'][:-1],rr['mean'][1:])[0,1]
plt.scatter(rr[:-1],rr[1:],label='correlation coefficient: {:.3f}'.format(corr))
plt.xlabel('$y_t$ (°C)')
plt.ylabel('$y_{t+1}$ (°C)')
plt.legend()
plt.title('Correlation monthly temperature average, seasonally adjusted')
# Out:
# Text(0.5, 1.0, 'Correlation monthly temperature average, seasonally adjusted')

# %%
def DailyTempPlots():

    tempData = df['average temperature'] #get data frame with just average temperature
    tempData.dropna(inplace=True) #drop all NaN years
    
    tempData.groupby(['month','day']).agg(['mean']).plot(style='rx',legend=False)
    for year in [1990,1991,1992,1993,1994,1995,1997]:#tempData.index.levels[0] :
        tempData.loc[year].plot(style='bx',legend=False)
    plt.xticks(np.arange(15,360,30), ('January','February','March','April','May','June','July','August','September',
                                'October','November','December'), rotation=45)
    plt.xlabel('day,month')
    plt.ylabel('average temperature (°C)')
    plt.title('daily temperature')
    
DailyTempPlots()
